# %%
# Dependencies
import requests
import pandas as pd
from census import Census

# %%
# File paths
path = "../Sales_info_with_taxes.csv"
study_results_path = "output_data/census.csv"

# Read the mouse data and the study results
sales_data = pd.read_csv(path)
census_data = pd.read_csv(study_results_path)

# %%
# Rename ZIP column in sales_data
sales_data = sales_data.rename(
    columns = {
        "ZIP": "Zipcode",
    }
)

# %%
# Combine the data into a single DataFrame
complete_df = pd.merge(sales_data, census_data, how="left", on=("Zipcode"))
# drop a column
complete_df.drop(columns='Unnamed: 0', inplace=True) 
complete_df.head()
# Out:
#    Count  Zipcode Type  Owner Occ?  Purchase Down %  Purchase Amt  \
# 0      1  11201.0  CND         0.0             33.0     4600000.0
# 1      1  11201.0  CND         0.0             30.0     4550000.0
# 2      1  11201.0  CND         0.0             69.0     2620000.0
# 3      1  11201.0  CND         0.0            100.0     4740000.0
# 4      1  11201.0  CND         0.0             81.0     4200000.0
#
#    Amount Mortgaged   Mtg Tx Pd  Mansion Tax Pd  New Sales Tax Amount  \
# 0         3062500.0  59718.7500         46000.0               41400.0
# 1         3185000.0  62107.5000         45500.0               40950.0
# 2          825084.0  16089.1380         26200.0               23580.0
# 3               0.0      0.0000         47400.0               42660.0
# 4          787743.0  15360.9885         42000.0               37800.0
#
#    Population  Median Age  Household Income  Per Capita Income  \
# 0     69755.0        35.1          163310.0           108933.0
# 1     69755.0        35.1          163310.0           108933.0
# 2     69755.0        35.1          163310.0           108933.0
# 3     69755.0        35.1          163310.0           108933.0
# 4     69755.0        35.1          163310.0           108933.0
#
#    Median Gross Rent  Poverty Count  Poverty Rate
# 0             3110.0         7004.0     10.040857
# 1             3110.0         7004.0     10.040857
# 2             3110.0         7004.0     10.040857
# 3             3110.0         7004.0     10.040857
# 4             3110.0         7004.0     10.040857

# %%
# prints the size of the dataframe
print('The size of the data frame is:',complete_df.shape)
# Out:
# The size of the data frame is: (17758, 17)

# %%
len(complete_df['Zipcode'].unique())
# Out:
# 47

# %%
# Verify if the data contains missing values
missing_data=complete_df.isnull()
for column in missing_data.columns:
    print(column)
    print(missing_data[column].value_counts()) 
    print("")
# Out:
# Count
# Count
# False    17758
# Name: count, dtype: int64
#
# Zipcode
# Zipcode
# False    17758
# Name: count, dtype: int64
#
# Type
# Type
# False    17758
# Name: count, dtype: int64
#
# Owner Occ?
# Owner Occ?
# False    17758
# Name: count, dtype: int64
#
# Purchase Down %
# Purchase Down %
# False    17758
# Name: count, dtype: int64
#
# Purchase Amt
# Purchase Amt
# False    17758
# Name: count, dtype: int64
#
# Amount Mortgaged
# Amount Mortgaged
# False    17758
# Name: count, dtype: int64
#
# Mtg Tx Pd
# Mtg Tx Pd
# False    17758
# Name: count, dtype: int64
#
# Mansion Tax Pd
# Mansion Tax Pd
# False    17758
# Name: count, dtype: int64
#
# New Sales Tax Amount
# New Sales Tax Amount
# False    17758
# Name: count, dtype: int64
#
# Population
# Population
# False    17701
# True        57
# Name: count, dtype: int64
#
# Median Age
# Median Age
# False    17701
# True        57
# Name: count, dtype: int64
#
# Household Income
# Household Income
# False    17701
# True        57
# Name: count, dtype: int64
#
# Per Capita Income
# Per Capita Income
# False    17701
# True        57
# Name: count, dtype: int64
#
# Median Gross Rent
# Median Gross Rent
# False    17701
# True        57
# Name: count, dtype: int64
#
# Poverty Count
# Poverty Count
# False    17701
# True        57
# Name: count, dtype: int64
#
# Poverty Rate
# Poverty Rate
# False    17701
# True        57
# Name: count, dtype: int64

# %%
# prints rows with missing values
complete_df[complete_df.isnull().any(axis=1)]
# Out:
#        Count  Zipcode                                               Type  \
# 2446       1  11243.0                                                CND
# 2447       1  11243.0                                                CND
# 2448       1  11243.0                                                CND
# 2449       1  11243.0                                                CND
# 2450       1  11243.0                                                CND
# 2451       1  11243.0                                                CND
# 2452       1  11243.0                                                CND
# 2453       1  11243.0                                                CND
# 2454       1  11243.0                                                CND
# 2455       1  11243.0                                                CND
# 2456       1  11243.0                                                CND
# 2457       1  11243.0                                                CND
# 2458       1  11243.0                                                CND
# 2459       1  11243.0                                                CND
# 2460       1  11243.0                                                CND
# 2461       1  11243.0                                                CND
# 2462       1  11243.0                                                CND
# 2463       1  11243.0                                                CND
# 2464       1  11243.0                                                CND
# 2465       1  11243.0                                                CND
# 2466       1  11243.0                                                CND
# 2467       1  11243.0                                                CND
# 2468       1  11243.0                                                CND
# 2469       1  11243.0                                                CND
# 2470       1  11243.0                                                CND
# 2471       1  11243.0                                                CND
# 2472       1  11243.0                                                CND
# 2473       1  11243.0                                                CND
# 7373       1      0.0  The information contained in this report is su...
# 8006       1      0.0  The information contained in this report is su...
# 8026       1      0.0  The information contained in this report is su...
# 10018      1  11243.0                                                CND
# 10019      1  11243.0                                                CND
# 10020      1  11243.0                                                CND
# 10021      1  11243.0                                                CND
# 10022      1  11243.0                                                CND
# 10023      1  11243.0                                                CND
# 10024      1  11243.0                                                CND
# 10025      1  11243.0                                                CND
# 10026      1  11243.0                                                CND
# 10027      1  11243.0                                                CND
# 10028      1  11243.0                                                CND
# 10029      1  11243.0                                                CND
# 10030      1  11243.0                                                CND
# 10031      1  11243.0                                                CND
# 10032      1  11243.0                                                CND
# 10033      1  11243.0                                                CND
# 10034      1  11243.0                                                CND
# 10035      1  11243.0                                                CND
# 10036      1  11243.0                                                CND
# 10037      1  11243.0                                                CND
# 10038      1  11243.0                                                CND
# 10039      1  11243.0                                                CND
# 10040      1  11243.0                                                CND
# 10041      1  11243.0                                                CND
# 10042      1  11243.0                                                CND
# 10043      1  11243.0                                                CND
#
#        Owner Occ?  Purchase Down %  Purchase Amt  Amount Mortgaged  \
# 2446          0.0             23.0      520000.0          400000.0
# 2447          0.0            100.0     1250000.0         1299556.0
# 2448          0.0             35.0     1668500.0               0.0
# 2449          0.0            100.0     1125000.0               0.0
# 2450          0.0             81.0      995000.0          184239.0
# 2451          0.0            100.0     1750000.0               0.0
# 2452          0.0            100.0      590000.0               0.0
# 2453          0.0             30.0      550000.0               0.0
# 2454          0.0             95.0    14250000.0          750000.0
# 2455          0.0             88.0     1695000.0          200000.0
# 2456          0.0             40.0     1050000.0          632708.0
# 2457          0.0             21.0     1070000.0          848000.0
# 2458          0.0             20.0     1530000.0         1224000.0
# 2459          0.0            100.0      967500.0               0.0
# 2460          0.0            100.0     1320000.0               0.0
# 2461          0.0            100.0     1485000.0               0.0
# 2462          0.0            100.0      449000.0               0.0
# 2463          0.0            100.0     1320000.0               0.0
# 2464          0.0             28.0     1699000.0         1220000.0
# 2465          0.0            100.0     1590000.0               0.0
# 2466          0.0            100.0      930000.0         1264000.0
# 2467          0.0            100.0     1400000.0               0.0
# 2468          0.0            100.0     1510000.0               0.0
# 2469          0.0             30.0      890000.0               0.0
# 2470          0.0             60.0     1340000.0          535000.0
# 2471          0.0             20.0      960000.0          768000.0
# 2472          0.0            100.0     3200000.0               0.0
# 2473          0.0            100.0      360000.0               0.0
# 7373          0.0              0.0           0.0               0.0
# 8006          0.0              0.0           0.0               0.0
# 8026          0.0              0.0           0.0               0.0
# 10018         1.0             20.0      995000.0          796000.0
# 10019         1.0             20.0     1510000.0         1216525.0
# 10020         1.0             35.0      850000.0          550000.0
# 10021         1.0            100.0      632000.0               0.0
# 10022         1.0             62.0     1525000.0          574360.0
# 10023         1.0             20.0      537500.0          430000.0
# 10024         1.0            100.0     1725000.0         1158482.0
# 10025         1.0             76.0      740000.0               0.0
# 10026         1.0             65.0     1325000.0          500000.0
# 10027         1.0             20.0     1899000.0         1519200.0
# 10028         1.0             30.0     1102500.0          770000.0
# 10029         1.0            100.0     1895000.0          354682.0
# 10030         1.0            100.0     2600000.0               0.0
# 10031         1.0            100.0     1625000.0               0.0
# 10032         1.0             20.0     1980125.0         1584100.0
# 10033         1.0             25.0     1558750.0         1188000.0
# 10034         1.0             20.0      999500.0          807600.0
# 10035         1.0             25.0     1915000.0         1436250.0
# 10036         1.0             20.0      775000.0          620000.0
# 10037         1.0            100.0     1540000.0               0.0
# 10038         1.0             20.0     2331200.0         1864950.0
# 10039         1.0             20.0     2250000.0         1800000.0
# 10040         1.0             35.0     2250000.0         1800000.0
# 10041         1.0              0.0     1400000.0          779471.0
# 10042         1.0             20.0     1575000.0         1260000.0
# 10043         1.0            100.0     1850000.0               0.0
#
#         Mtg Tx Pd  Mansion Tax Pd  New Sales Tax Amount  Population  \
# 2446    7200.0000            0.00             7280.0000         NaN
# 2447   25341.3420        12500.00            11250.0000         NaN
# 2448       0.0000        16685.00            15016.5000         NaN
# 2449       0.0000        11250.00            10125.0000         NaN
# 2450    3316.3020            0.00            13930.0000         NaN
# 2451       0.0000        17500.00            15750.0000         NaN
# 2452       0.0000            0.00             8260.0000         NaN
# 2453       0.0000            0.00             7700.0000         NaN
# 2454   14625.0000       142500.00           128250.0000         NaN
# 2455    3600.0000        16950.00            15255.0000         NaN
# 2456   12337.8060        10500.00             9450.0000         NaN
# 2457   16536.0000        10700.00             9630.0000         NaN
# 2458   23868.0000        15300.00            13770.0000         NaN
# 2459       0.0000            0.00            13545.0000         NaN
# 2460       0.0000        13200.00            11880.0000         NaN
# 2461       0.0000        14850.00            13365.0000         NaN
# 2462       0.0000            0.00             6286.0000         NaN
# 2463       0.0000        13200.00            11880.0000         NaN
# 2464   23790.0000        16990.00            15291.0000         NaN
# 2465       0.0000        15900.00            14310.0000         NaN
# 2466   24648.0000            0.00            13020.0000         NaN
# 2467       0.0000        14000.00            12600.0000         NaN
# 2468       0.0000        15100.00            13590.0000         NaN
# 2469       0.0000            0.00            12460.0000         NaN
# 2470   10432.5000        13400.00            12060.0000         NaN
# 2471   14976.0000            0.00            13440.0000         NaN
# 2472       0.0000        32000.00            28800.0000         NaN
# 2473       0.0000            0.00             5040.0000         NaN
# 7373       0.0000            0.00                0.0000         NaN
# 8006       0.0000            0.00                0.0000         NaN
# 8026       0.0000            0.00                0.0000         NaN
# 10018  15522.0000            0.00            44158.1000         NaN
# 10019  23722.2375        15100.00            67013.8000         NaN
# 10020  10725.0000            0.00            37723.0000         NaN
# 10021      0.0000            0.00            28048.1600         NaN
# 10022  11200.0200        15250.00            67679.5000         NaN
# 10023   7740.0000            0.00            23854.2500         NaN
# 10024  22590.3990        17250.00            76555.5000         NaN
# 10025      0.0000            0.00            32841.2000         NaN
# 10026   9750.0000        13250.00            58803.5000         NaN
# 10027  29624.4000        18990.00            84277.6200         NaN
# 10028  15015.0000        11025.00            48928.9500         NaN
# 10029   6384.2760        18950.00            84100.1000         NaN
# 10030      0.0000        26000.00           115388.0000         NaN
# 10031      0.0000        16250.00            72117.5000         NaN
# 10032  30889.9500        19801.25            87877.9475         NaN
# 10033  23166.0000        15587.50            69177.3250         NaN
# 10034  15748.2000            0.00            44357.8100         NaN
# 10035  28006.8750        19150.00            84987.7000         NaN
# 10036  12090.0000            0.00            34394.5000         NaN
# 10037      0.0000        15400.00            68345.2000         NaN
# 10038  36366.5250        23312.00           103458.6560         NaN
# 10039  35100.0000        22500.00            99855.0000         NaN
# 10040  35100.0000        22500.00            99855.0000         NaN
# 10041  15199.6845        14000.00            62132.0000         NaN
# 10042  24570.0000        15750.00            69898.5000         NaN
# 10043      0.0000        18500.00            82103.0000         NaN
#
#        Median Age  Household Income  Per Capita Income  Median Gross Rent  \
# 2446          NaN               NaN                NaN                NaN
# 2447          NaN               NaN                NaN                NaN
# 2448          NaN               NaN                NaN                NaN
# 2449          NaN               NaN                NaN                NaN
# 2450          NaN               NaN                NaN                NaN
# 2451          NaN               NaN                NaN                NaN
# 2452          NaN               NaN                NaN                NaN
# 2453          NaN               NaN                NaN                NaN
# 2454          NaN               NaN                NaN                NaN
# 2455          NaN               NaN                NaN                NaN
# 2456          NaN               NaN                NaN                NaN
# 2457          NaN               NaN                NaN                NaN
# 2458          NaN               NaN                NaN                NaN
# 2459          NaN               NaN                NaN                NaN
# 2460          NaN               NaN                NaN                NaN
# 2461          NaN               NaN                NaN                NaN
# 2462          NaN               NaN                NaN                NaN
# 2463          NaN               NaN                NaN                NaN
# 2464          NaN               NaN                NaN                NaN
# 2465          NaN               NaN                NaN                NaN
# 2466          NaN               NaN                NaN                NaN
# 2467          NaN               NaN                NaN                NaN
# 2468          NaN               NaN                NaN                NaN
# 2469          NaN               NaN                NaN                NaN
# 2470          NaN               NaN                NaN                NaN
# 2471          NaN               NaN                NaN                NaN
# 2472          NaN               NaN                NaN                NaN
# 2473          NaN               NaN                NaN                NaN
# 7373          NaN               NaN                NaN                NaN
# 8006          NaN               NaN                NaN                NaN
# 8026          NaN               NaN                NaN                NaN
# 10018         NaN               NaN                NaN                NaN
# 10019         NaN               NaN                NaN                NaN
# 10020         NaN               NaN                NaN                NaN
# 10021         NaN               NaN                NaN                NaN
# 10022         NaN               NaN                NaN                NaN
# 10023         NaN               NaN                NaN                NaN
# 10024         NaN               NaN                NaN                NaN
# 10025         NaN               NaN                NaN                NaN
# 10026         NaN               NaN                NaN                NaN
# 10027         NaN               NaN                NaN                NaN
# 10028         NaN               NaN                NaN                NaN
# 10029         NaN               NaN                NaN                NaN
# 10030         NaN               NaN                NaN                NaN
# 10031         NaN               NaN                NaN                NaN
# 10032         NaN               NaN                NaN                NaN
# 10033         NaN               NaN                NaN                NaN
# 10034         NaN               NaN                NaN                NaN
# 10035         NaN               NaN                NaN                NaN
# 10036         NaN               NaN                NaN                NaN
# 10037         NaN               NaN                NaN                NaN
# 10038         NaN               NaN                NaN                NaN
# 10039         NaN               NaN                NaN                NaN
# 10040         NaN               NaN                NaN                NaN
# 10041         NaN               NaN                NaN                NaN
# 10042         NaN               NaN                NaN                NaN
# 10043         NaN               NaN                NaN                NaN
#
#        Poverty Count  Poverty Rate
# 2446             NaN           NaN
# 2447             NaN           NaN
# 2448             NaN           NaN
# 2449             NaN           NaN
# 2450             NaN           NaN
# 2451             NaN           NaN
# 2452             NaN           NaN
# 2453             NaN           NaN
# 2454             NaN           NaN
# 2455             NaN           NaN
# 2456             NaN           NaN
# 2457             NaN           NaN
# 2458             NaN           NaN
# 2459             NaN           NaN
# 2460             NaN           NaN
# 2461             NaN           NaN
# 2462             NaN           NaN
# 2463             NaN           NaN
# 2464             NaN           NaN
# 2465             NaN           NaN
# 2466             NaN           NaN
# 2467             NaN           NaN
# 2468             NaN           NaN
# 2469             NaN           NaN
# 2470             NaN           NaN
# 2471             NaN           NaN
# 2472             NaN           NaN
# 2473             NaN           NaN
# 7373             NaN           NaN
# 8006             NaN           NaN
# 8026             NaN           NaN
# 10018            NaN           NaN
# 10019            NaN           NaN
# 10020            NaN           NaN
# 10021            NaN           NaN
# 10022            NaN           NaN
# 10023            NaN           NaN
# 10024            NaN           NaN
# 10025            NaN           NaN
# 10026            NaN           NaN
# 10027            NaN           NaN
# 10028            NaN           NaN
# 10029            NaN           NaN
# 10030            NaN           NaN
# 10031            NaN           NaN
# 10032            NaN           NaN
# 10033            NaN           NaN
# 10034            NaN           NaN
# 10035            NaN           NaN
# 10036            NaN           NaN
# 10037            NaN           NaN
# 10038            NaN           NaN
# 10039            NaN           NaN
# 10040            NaN           NaN
# 10041            NaN           NaN
# 10042            NaN           NaN
# 10043            NaN           NaN

# %%
# drop rows with Nan values
complete_df.drop(index=[2446,2447,2448,2449,2450,2451,2452,2453,2454,2455,2456,2457,
2458,2459,2460,2461,2462,2463,2464,2465,2466,2467,2468,2469,2470,2471,2472,2473,7373,
8006,8026,10018,10019,10020,10021,10022,10023,10024,10025,10026,10027,10028,10029,10030,
10031,10032,10033,10034,10035,10036,10037,10038,10039,10040,10041,10042,10043,], inplace=True)

# %%
# print number of missing data in the dataset
print('The number of missing data in the dataset is:',complete_df.isnull().sum().sum())
# Out:
# The number of missing data in the dataset is: 0

# %%
# check datatypes
complete_df.dtypes
# Out:
# Count                     int64
# Zipcode                 float64
# Type                     object
# Owner Occ?              float64
# Purchase Down %         float64
# Purchase Amt            float64
# Amount Mortgaged        float64
# Mtg Tx Pd               float64
# Mansion Tax Pd          float64
# New Sales Tax Amount    float64
# Population              float64
# Median Age              float64
# Household Income        float64
# Per Capita Income       float64
# Median Gross Rent       float64
# Poverty Count           float64
# Poverty Rate            float64
# dtype: object

# %%
# change datatype for zipcode
complete_df['Zipcode']=complete_df['Zipcode'].astype('int64')

# %%
# reset indeces
complete_df.reset_index(drop=True, inplace=True)

# %%
# Export the City_Data into a csv
complete_df.to_csv("../complete.csv", encoding="utf-8", index=False)

# %%
# # Useful code

# # Data cleaning

# # prints the size of the dataframe
# print('The size of the data frame is:',census_df.shape) 

# # drop a certain column
# census_df.drop(columns='Unnamed: 0', inplace=True) 

# census_df['electric_eui'].replace(np.nan, census_df['Median Age'].mean(), inplace=True)

# # Find number of missing values for each column
# missing_data=census_pd.isnull()
# for column in missing_data.columns:
#     print(column)
#     print(missing_data[column].value_counts()) 
#     print("")

# # prints rows with missing values
# census_pd[census_pd.isnull().any(axis=1)]

# # reset indeces
# census_pd.reset_index(drop=True, inplace=True)

# # print datatypes
# census_pd.dtypes

# # change datatype
# census_pd['Median Age']=census_pd['Median Age'].astype('int')

# # Exploratory Data Analysis

# # .describe
# census_pd[['columns']].describe()
